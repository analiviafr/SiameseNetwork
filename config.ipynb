# %%
train_dir = '../input/signature-verification-dataset/sign_data/train'
testi_dir = '../input/signature-verification-dataset/sign_data/test'
batch_size = 32
epochs = 20
